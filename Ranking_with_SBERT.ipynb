# %% [markdown]
# #### Predicting and Ranking Candidate using SBERT model

# %% [markdown]
# #### Import libraries

# %% [markdown]
# #### Load the Cleaned dataset

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
file_path = r"C:\Users\USER\Documents\Potential_Talent\cleaned_dataset.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 ct bauer college of business graduate mag...
# 1   2  native english teacher at epik english program...
# 2   3              aspiring human resources professional
# 3   4             people development coordinator at ryan
# 4   5    advisory board member at celal bayar university
#
#                             location  connection  fit
# 0                      houston texas    0.168337  NaN
# 1                             kanada    1.000000  NaN
# 2  raleighdurham north carolina area    0.086172  NaN
# 3                       denton texas    1.000000  NaN
# 4                       izmir trkiye    1.000000  NaN

# %% [markdown]
# #### Combine relevant columns to form a text column with a longer sentences as requied by Sbert

# %% [markdown]
# Codes below combine job_title, location and connection to creat text column

# %%
# Combine relevant columns into one string
df["text"] = (
    df["job_title"].fillna("") + " "
    + df["location"].fillna("") + " "
    + df["connection"].astype(str).fillna("")
)

df.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 ct bauer college of business graduate mag...
# 1   2  native english teacher at epik english program...
# 2   3              aspiring human resources professional
# 3   4             people development coordinator at ryan
# 4   5    advisory board member at celal bayar university
#
#                             location  connection  fit  \
# 0                      houston texas    0.168337  NaN
# 1                             kanada    1.000000  NaN
# 2  raleighdurham north carolina area    0.086172  NaN
# 3                       denton texas    1.000000  NaN
# 4                       izmir trkiye    1.000000  NaN
#
#                                                 text
# 0  2019 ct bauer college of business graduate mag...
# 1  native english teacher at epik english program...
# 2  aspiring human resources professional raleighd...
# 3  people development coordinator at ryan denton ...
# 4  advisory board member at celal bayar universit...

# %% [markdown]
# Result above shown that text column has been created

# %% [markdown]
# #### Drop fit column since it is emppty

# %%
df = df.drop(columns = ['fit'])

# %%
df.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 ct bauer college of business graduate mag...
# 1   2  native english teacher at epik english program...
# 2   3              aspiring human resources professional
# 3   4             people development coordinator at ryan
# 4   5    advisory board member at celal bayar university
#
#                             location  connection  \
# 0                      houston texas    0.168337
# 1                             kanada    1.000000
# 2  raleighdurham north carolina area    0.086172
# 3                       denton texas    1.000000
# 4                       izmir trkiye    1.000000
#
#                                                 text
# 0  2019 ct bauer college of business graduate mag...
# 1  native english teacher at epik english program...
# 2  aspiring human resources professional raleighd...
# 3  people development coordinator at ryan denton ...
# 4  advisory board member at celal bayar universit...

# %% [markdown]
# #### Load pretrained SBERT

# %%
# Load SBERT model
model = SentenceTransformer('all-MiniLM-L6-v2')

# %% [markdown]
# **Vectorize the text column using embedding from sbert**

# %%
# Compute embeddings for all rows
embeddings = model.encode(df['text'].tolist(), show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# #### Convert the embedding scores to pandas dataframe

# %%
embedding_df = pd.DataFrame(embeddings)
embedding_df.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.080647 -0.013590  0.025604  0.045382 -0.054794  0.027669 -0.092094
# 1  0.013974  0.002556  0.058640  0.008864 -0.036880 -0.017276  0.064799
# 2 -0.032880  0.020700 -0.036080  0.101873 -0.036267  0.003642 -0.018970
# 3 -0.077126 -0.016689 -0.015529  0.038083 -0.028124 -0.031241  0.033025
# 4 -0.101833  0.050485 -0.035294  0.002843 -0.078087 -0.100537  0.073505
#
#         7         8         9    ...       374       375       376       377  \
# 0 -0.024126 -0.018790 -0.041619  ...  0.035383 -0.039114  0.014456 -0.021426
# 1  0.008673 -0.059727  0.091424  ...  0.033897  0.073916 -0.029386 -0.065074
# 2 -0.053405 -0.043835  0.063150  ...  0.098044  0.006575  0.034576  0.017100
# 3 -0.060054 -0.041687  0.004289  ...  0.054908 -0.012562  0.026102 -0.046238
# 4  0.023797 -0.031542  0.004224  ...  0.017321  0.074921 -0.010447  0.072482
#
#         378       379       380       381       382       383
# 0 -0.080527  0.010414  0.059675 -0.064236  0.023765  0.004547
# 1 -0.066251 -0.024638  0.049792  0.022195 -0.085590  0.064956
# 2 -0.052237  0.079505  0.025924 -0.034924 -0.026293  0.028292
# 3 -0.028634 -0.014254 -0.071070  0.003787 -0.003871  0.008868
# 4 -0.072462 -0.046297  0.093996 -0.018277 -0.092328 -0.028491
#
# [5 rows x 384 columns]

# %% [markdown]
# #### Rename the embedding scores columns 0, 1,2,3..... to embedding_0, embedding_1 ......

# %%
# Rename columns
embedding_df.columns = [f"embedding_{i}" for i in range(embedding_df.shape[1])]
embedding_df.head()
# Out:
#    embedding_0  embedding_1  embedding_2  embedding_3  embedding_4  \
# 0    -0.080647    -0.013590     0.025604     0.045382    -0.054794
# 1     0.013974     0.002556     0.058640     0.008864    -0.036880
# 2    -0.032880     0.020700    -0.036080     0.101873    -0.036267
# 3    -0.077126    -0.016689    -0.015529     0.038083    -0.028124
# 4    -0.101833     0.050485    -0.035294     0.002843    -0.078087
#
#    embedding_5  embedding_6  embedding_7  embedding_8  embedding_9  ...  \
# 0     0.027669    -0.092094    -0.024126    -0.018790    -0.041619  ...
# 1    -0.017276     0.064799     0.008673    -0.059727     0.091424  ...
# 2     0.003642    -0.018970    -0.053405    -0.043835     0.063150  ...
# 3    -0.031241     0.033025    -0.060054    -0.041687     0.004289  ...
# 4    -0.100537     0.073505     0.023797    -0.031542     0.004224  ...
#
#    embedding_374  embedding_375  embedding_376  embedding_377  embedding_378  \
# 0       0.035383      -0.039114       0.014456      -0.021426      -0.080527
# 1       0.033897       0.073916      -0.029386      -0.065074      -0.066251
# 2       0.098044       0.006575       0.034576       0.017100      -0.052237
# 3       0.054908      -0.012562       0.026102      -0.046238      -0.028634
# 4       0.017321       0.074921      -0.010447       0.072482      -0.072462
#
#    embedding_379  embedding_380  embedding_381  embedding_382  embedding_383
# 0       0.010414       0.059675      -0.064236       0.023765       0.004547
# 1      -0.024638       0.049792       0.022195      -0.085590       0.064956
# 2       0.079505       0.025924      -0.034924      -0.026293       0.028292
# 3      -0.014254      -0.071070       0.003787      -0.003871       0.008868
# 4      -0.046297       0.093996      -0.018277      -0.092328      -0.028491
#
# [5 rows x 384 columns]

# %% [markdown]
# #### Add the embedding scores back to the original dataframe

# %%
# Concatenate with original df
df = pd.concat([df.reset_index(drop=True), embedding_df], axis=1)

df.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 ct bauer college of business graduate mag...
# 1   2  native english teacher at epik english program...
# 2   3              aspiring human resources professional
# 3   4             people development coordinator at ryan
# 4   5    advisory board member at celal bayar university
#
#                             location  connection  \
# 0                      houston texas    0.168337
# 1                             kanada    1.000000
# 2  raleighdurham north carolina area    0.086172
# 3                       denton texas    1.000000
# 4                       izmir trkiye    1.000000
#
#                                                 text  embedding_0  \
# 0  2019 ct bauer college of business graduate mag...    -0.080647
# 1  native english teacher at epik english program...     0.013974
# 2  aspiring human resources professional raleighd...    -0.032880
# 3  people development coordinator at ryan denton ...    -0.077126
# 4  advisory board member at celal bayar universit...    -0.101833
#
#    embedding_1  embedding_2  embedding_3  embedding_4  ...  embedding_374  \
# 0    -0.013590     0.025604     0.045382    -0.054794  ...       0.035383
# 1     0.002556     0.058640     0.008864    -0.036880  ...       0.033897
# 2     0.020700    -0.036080     0.101873    -0.036267  ...       0.098044
# 3    -0.016689    -0.015529     0.038083    -0.028124  ...       0.054908
# 4     0.050485    -0.035294     0.002843    -0.078087  ...       0.017321
#
#    embedding_375  embedding_376  embedding_377  embedding_378  embedding_379  \
# 0      -0.039114       0.014456      -0.021426      -0.080527       0.010414
# 1       0.073916      -0.029386      -0.065074      -0.066251      -0.024638
# 2       0.006575       0.034576       0.017100      -0.052237       0.079505
# 3      -0.012562       0.026102      -0.046238      -0.028634      -0.014254
# 4       0.074921      -0.010447       0.072482      -0.072462      -0.046297
#
#    embedding_380  embedding_381  embedding_382  embedding_383
# 0       0.059675      -0.064236       0.023765       0.004547
# 1       0.049792       0.022195      -0.085590       0.064956
# 2       0.025924      -0.034924      -0.026293       0.028292
# 3      -0.071070       0.003787      -0.003871       0.008868
# 4       0.093996      -0.018277      -0.092328      -0.028491
#
# [5 rows x 389 columns]

# %% [markdown]
# #### Define keywords: Aspiring human resources", "Seeking human resources

# %%
# Define your keywords
keywords = ["aspiring human resources", "seeking human resources"]

# %% [markdown]
# #### Compute embeddings for the keywords

# %%
# Compute embeddings for all target keywords
keywords_embeddings = model.encode(keywords, normalize_embeddings=True)  # shape: (2, embedding_dim)

# %% [markdown]
# #### Compute cosine similarity b/w the vectorised text column and the keywords

# %%
# Compute cosine similarity of each candidate to each target keyword
# embeddings: your candidate embeddings, shape (num_candidates, embedding_dim)
similarities = cosine_similarity(embeddings, keywords_embeddings)  # shape: (num_candidates, 2)

# %%
# Take the max similarity for each candidate
df['similarity_score'] = similarities.max(axis=1)

# %%
#  sorted by similarity score descending
df[['id', 'job_title', 'similarity_score']].sort_values('similarity_score', ascending=False).head(20)
# Out:
#       id                                          job_title  similarity_score
# 98    99                   seeking human resources position          0.757853
# 5      6                aspiring human resources specialist          0.754887
# 35    36                aspiring human resources specialist          0.754887
# 23    24                aspiring human resources specialist          0.754887
# 48    49                aspiring human resources specialist          0.754887
# 59    60                aspiring human resources specialist          0.754887
# 29    30              seeking human resources opportunities          0.740008
# 27    28              seeking human resources opportunities          0.740008
# 20    21              aspiring human resources professional          0.734231
# 2      3              aspiring human resources professional          0.734231
# 16    17              aspiring human resources professional          0.734231
# 45    46              aspiring human resources professional          0.734231
# 57    58              aspiring human resources professional          0.734231
# 32    33              aspiring human resources professional          0.734231
# 39    40  seeking human resources hris and generalist po...          0.727430
# 9     10  seeking human resources hris and generalist po...          0.727430
# 52    53  seeking human resources hris and generalist po...          0.727430
# 61    62  seeking human resources hris and generalist po...          0.727430
# 100  101              human resources generalist at loparex          0.696288
# 81    82  aspiring human resources professional an energ...          0.690004
