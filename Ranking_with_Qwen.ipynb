# %% [markdown]
# #### Ranking with Qwen using prompt method

# %% [markdown]
# #### Load libraries

# %%
import pandas as pd
import json
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
import re

# %% [markdown]
# #### Load Dataset

# %%
file_path = r"C:\Users\USER\Documents\Potential_Talent\potential-talents - Aspiring human resources - seeking human resources.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 C.T. Bauer College of Business Graduate (...
# 1   2  Native English Teacher at EPIK (English Progra...
# 2   3              Aspiring Human Resources Professional
# 3   4             People Development Coordinator at Ryan
# 4   5    Advisory Board Member at Celal Bayar University
#
#                               location connection  fit
# 0                       Houston, Texas         85  NaN
# 1                               Kanada      500+   NaN
# 2  Raleigh-Durham, North Carolina Area         44  NaN
# 3                        Denton, Texas      500+   NaN
# 4                       İzmir, Türkiye      500+   NaN

# %% [markdown]
# #### Drop fit column

# %%
df = df.drop(columns = ['fit'])
df.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 C.T. Bauer College of Business Graduate (...
# 1   2  Native English Teacher at EPIK (English Progra...
# 2   3              Aspiring Human Resources Professional
# 3   4             People Development Coordinator at Ryan
# 4   5    Advisory Board Member at Celal Bayar University
#
#                               location connection
# 0                       Houston, Texas         85
# 1                               Kanada      500+
# 2  Raleigh-Durham, North Carolina Area         44
# 3                        Denton, Texas      500+
# 4                       İzmir, Türkiye      500+

# %% [markdown]
# #### Create text column

# %%
df["text"] = (
    df["job_title"].astype(str).str.lower() + ", " 
    + df["location"].astype(str).str.lower() 
    + " (connections: " + df["connection"].astype(str) + ")"
)

df.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 C.T. Bauer College of Business Graduate (...
# 1   2  Native English Teacher at EPIK (English Progra...
# 2   3              Aspiring Human Resources Professional
# 3   4             People Development Coordinator at Ryan
# 4   5    Advisory Board Member at Celal Bayar University
#
#                               location connection  \
# 0                       Houston, Texas         85
# 1                               Kanada      500+
# 2  Raleigh-Durham, North Carolina Area         44
# 3                        Denton, Texas      500+
# 4                       İzmir, Türkiye      500+
#
#                                                 text
# 0  2019 c.t. bauer college of business graduate (...
# 1  native english teacher at epik (english progra...
# 2  aspiring human resources professional, raleigh...
# 3  people development coordinator at ryan, denton...
# 4  advisory board member at celal bayar universit...

# %% [markdown]
# #### Extract text column from df

# %%
text_series = df["text"]

for t in text_series.head():
    print(t)
# Out:
# 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# native english teacher at epik (english program in korea), kanada (connections: 500+ )
# aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# people development coordinator at ryan, denton, texas (connections: 500+ )
# advisory board member at celal bayar university, i̇zmir, türkiye (connections: 500+ )

# %% [markdown]
# #### Split text series into chunks such that each chunk has 8 rows

# %%
chunk_size = 8
chunks = [text_series[i:i + chunk_size] for i in range(0, len(text_series), chunk_size)]

print(f"Number of chunks: {len(chunks)}")

for idx, chunk in enumerate(chunks):
    print(f"\nChunk {idx+1} (size {len(chunk)}):")
    for item in chunk:
        print(item)
# Out:
# Number of chunks: 13
#
# Chunk 1 (size 8):
# 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# native english teacher at epik (english program in korea), kanada (connections: 500+ )
# aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# people development coordinator at ryan, denton, texas (connections: 500+ )
# advisory board member at celal bayar university, i̇zmir, türkiye (connections: 500+ )
# aspiring human resources specialist, greater new york city area (connections: 1)
# student at humber college and aspiring human resources generalist, kanada (connections: 61)
# hr senior specialist, san francisco bay area (connections: 500+ )
#
# Chunk 2 (size 8):
# student at humber college and aspiring human resources generalist, kanada (connections: 61)
# seeking human resources hris and generalist positions, greater philadelphia area (connections: 500+ )
# student at chapman university, lake forest, california (connections: 2)
# svp, chro, marketing & communications, csr officer | engie | houston | the woodlands | energy | gphr | sphr, houston, texas area (connections: 500+ )
# human resources coordinator at intercontinental buckhead atlanta, atlanta, georgia (connections: 500+ )
# 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# native english teacher at epik (english program in korea), kanada (connections: 500+ )
#
# Chunk 3 (size 8):
# aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# people development coordinator at ryan, denton, texas (connections: 500+ )
# 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# native english teacher at epik (english program in korea), kanada (connections: 500+ )
# aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# people development coordinator at ryan, denton, texas (connections: 500+ )
# advisory board member at celal bayar university, i̇zmir, türkiye (connections: 500+ )
# aspiring human resources specialist, greater new york city area (connections: 1)
#
# Chunk 4 (size 8):
# student at humber college and aspiring human resources generalist, kanada (connections: 61)
# hr senior specialist, san francisco bay area (connections: 500+ )
# aspiring human resources management student seeking an internship, houston, texas area (connections: 500+ )
# seeking human resources opportunities, chicago, illinois (connections: 390)
# aspiring human resources management student seeking an internship, houston, texas area (connections: 500+ )
# seeking human resources opportunities, chicago, illinois (connections: 390)
# 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# native english teacher at epik (english program in korea), kanada (connections: 500+ )
#
# Chunk 5 (size 8):
# aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# people development coordinator at ryan, denton, texas (connections: 500+ )
# advisory board member at celal bayar university, i̇zmir, türkiye (connections: 500+ )
# aspiring human resources specialist, greater new york city area (connections: 1)
# student at humber college and aspiring human resources generalist, kanada (connections: 61)
# hr senior specialist, san francisco bay area (connections: 500+ )
# student at humber college and aspiring human resources generalist, kanada (connections: 61)
# seeking human resources hris and generalist positions, greater philadelphia area (connections: 500+ )
#
# Chunk 6 (size 8):
# student at chapman university, lake forest, california (connections: 2)
# svp, chro, marketing & communications, csr officer | engie | houston | the woodlands | energy | gphr | sphr, houston, texas area (connections: 500+ )
# human resources coordinator at intercontinental buckhead atlanta, atlanta, georgia (connections: 500+ )
# 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# native english teacher at epik (english program in korea), kanada (connections: 500+ )
# aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# people development coordinator at ryan, denton, texas (connections: 500+ )
# advisory board member at celal bayar university, i̇zmir, türkiye (connections: 500+ )
#
# Chunk 7 (size 8):
# aspiring human resources specialist, greater new york city area (connections: 1)
# student at humber college and aspiring human resources generalist, kanada (connections: 61)
# hr senior specialist, san francisco bay area (connections: 500+ )
# student at humber college and aspiring human resources generalist, kanada (connections: 61)
# seeking human resources hris and generalist positions, greater philadelphia area (connections: 500+ )
# student at chapman university, lake forest, california (connections: 2)
# svp, chro, marketing & communications, csr officer | engie | houston | the woodlands | energy | gphr | sphr, houston, texas area (connections: 500+ )
# human resources coordinator at intercontinental buckhead atlanta, atlanta, georgia (connections: 500+ )
#
# Chunk 8 (size 8):
# 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# people development coordinator at ryan, denton, texas (connections: 500+ )
# aspiring human resources specialist, greater new york city area (connections: 1)
# hr senior specialist, san francisco bay area (connections: 500+ )
# seeking human resources hris and generalist positions, greater philadelphia area (connections: 500+ )
# student at chapman university, lake forest, california (connections: 2)
# svp, chro, marketing & communications, csr officer | engie | houston | the woodlands | energy | gphr | sphr, houston, texas area (connections: 500+ )
#
# Chunk 9 (size 8):
# human resources coordinator at intercontinental buckhead atlanta, atlanta, georgia (connections: 500+ )
# experienced retail manager and aspiring human resources professional, austin, texas area (connections: 57)
# human resources, staffing and recruiting professional, jackson, mississippi area (connections: 500+ )
# human resources specialist at luxottica, greater new york city area (connections: 500+ )
# director of human resources north america, groupe beneteau, greater grand rapids, michigan area (connections: 500+ )
# retired army national guard recruiter, office manager,  seeking a position in human resources., virginia beach, virginia (connections: 82)
# human resources generalist at scottmadden, inc., raleigh-durham, north carolina area (connections: 500+ )
# business management major and aspiring human resources manager, monroe, louisiana area (connections: 5)
#
# Chunk 10 (size 8):
# aspiring human resources manager, seeking internship in human resources., houston, texas area (connections: 7)
# human resources professional, greater boston area (connections: 16)
# nortia staffing is seeking human resources, payroll & administrative professionals!!  (408) 709-2621, san jose, california (connections: 500+ )
# aspiring human resources professional | passionate about helping to create an inclusive and engaging work environment, new york, new york (connections: 212)
# human resources|
# conflict management|
# policies & procedures|talent management|benefits & compensation, dallas/fort worth area (connections: 409)
# human resources generalist at schwan's, amerika birleşik devletleri (connections: 500+ )
# liberal arts major. aspiring human resources analyst., baton rouge, louisiana area (connections: 7)
# junior mes engineer| information systems, myrtle beach, south carolina area (connections: 52)
#
# Chunk 11 (size 8):
# senior human resources business partner at heil environmental, chattanooga, tennessee area (connections: 455)
# aspiring human resources professional | an energetic and team-focused leader, austin, texas area (connections: 174)
# hr manager at endemol shine north america, los angeles, california (connections: 268)
# human resources professional for the world leader in gis software, highland, california (connections: 50)
# rrp brand portfolio executive at jti (japan tobacco international), greater philadelphia area (connections: 500+ )
# information systems specialist and programmer with a love for data and organization., gaithersburg, maryland (connections: 4)
# bachelor of science in biology from victoria university of wellington, baltimore, maryland (connections: 40)
# human resources management major, milpitas, california (connections: 18)
#
# Chunk 12 (size 8):
# director human resources  at ey, greater atlanta area (connections: 349)
# undergraduate research assistant at styczynski lab, greater atlanta area (connections: 155)
# lead official at western illinois university, greater chicago area (connections: 39)
# seeking employment opportunities within customer service or patient care, torrance, california (connections: 64)
# admissions representative at community medical center long beach, long beach, california (connections: 9)
# seeking human  resources opportunities. open to travel and relocation., amerika birleşik devletleri (connections: 415)
# student at westfield state university, bridgewater, massachusetts (connections: 57)
# student at indiana university kokomo - business management -
# retail manager at delphi hardware and paint, lafayette, indiana (connections: 19)
#
# Chunk 13 (size 8):
# aspiring human resources professional, kokomo, indiana area (connections: 71)
# student, houston, texas area (connections: 4)
# seeking human resources position, las vegas, nevada area (connections: 48)
# aspiring human resources manager | graduating may 2020 | seeking an entry-level human resources position in st. louis, cape girardeau, missouri (connections: 103)
# human resources generalist at loparex, raleigh-durham, north carolina area (connections: 500+ )
# business intelligence and analytics at travelers, greater new york city area (connections: 49)
# always set them up for success, greater los angeles area (connections: 500+ )
# director of administration at excellence logging, katy, texas (connections: 500+ )

# %% [markdown]
# #### Load pretrained model and tokenizer

# %%
save_directory = r"C:\Users\USER\Documents\Potential Talent\Qwen_2.5-3b"

tokenizer = AutoTokenizer.from_pretrained(save_directory)
model = AutoModelForCausalLM.from_pretrained(
    save_directory,
    torch_dtype=torch.float32,
    device_map=None
).to("cpu")
print("model and tokenizer loaded")
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model and tokenizer loaded

# %% [markdown]
# #### Define keywords and state instructions

# %%
keywords = "aspiring human resources OR seeking human resources"

chunk_instructions = []

for chunk_idx, chunk in enumerate(chunks, start=1):

    instruction = f"""
Rank each candidate for relevance to: "{keywords}"

IMPORTANT:
- Output ONLY a JSON array.
- Each item must have "index" and "score".
- Score must be between 0 and 1.
- Include ALL candidates.
- Round scores to EXACTLY 2 decimals.
- Do NOT truncate output.
- Do NOT duplicate candidate

Example (do NOT copy scores):
[
  {{"index": 1, "score": <score>}},
  {{"index": 2, "score": <score>}}
]

Candidates:
"""

    for i, text in enumerate(chunk, start=1):
        instruction += f"{i}. {text}\n"

    chunk_instructions.append(instruction)

    print(f"\n--- Chunk {chunk_idx} Instruction ---")
    print(instruction)
# Out:
# --- Chunk 1 Instruction ---
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# 2. native english teacher at epik (english program in korea), kanada (connections: 500+ )
# 3. aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# 4. people development coordinator at ryan, denton, texas (connections: 500+ )
# 5. advisory board member at celal bayar university, i̇zmir, türkiye (connections: 500+ )
# 6. aspiring human resources specialist, greater new york city area (connections: 1)
# 7. student at humber college and aspiring human resources generalist, kanada (connections: 61)
# 8. hr senior specialist, san francisco bay area (connections: 500+ )
#
#
# --- Chunk 2 Instruction ---
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. student at humber college and aspiring human resources generalist, kanada (connections: 61)
# 2. seeking human resources hris and generalist positions, greater philadelphia area (connections: 500+ )
# 3. student at chapman university, lake forest, california (connections: 2)
# 4. svp, chro, marketing & communications, csr officer | engie | houston | the woodlands | energy | gphr | sphr, houston, texas area (connections: 500+ )
# 5. human resources coordinator at intercontinental buckhead atlanta, atlanta, georgia (connections: 500+ )
# 6. 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# 7. 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# 8. native english teacher at epik (english program in korea), kanada (connections: 500+ )
#
#
# --- Chunk 3 Instruction ---
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# 2. people development coordinator at ryan, denton, texas (connections: 500+ )
# 3. 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# 4. native english teacher at epik (english program in korea), kanada (connections: 500+ )
# 5. aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# 6. people development coordinator at ryan, denton, texas (connections: 500+ )
# 7. advisory board member at celal bayar university, i̇zmir, türkiye (connections: 500+ )
# 8. aspiring human resources specialist, greater new york city area (connections: 1)
#
#
# --- Chunk 4 Instruction ---
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. student at humber college and aspiring human resources generalist, kanada (connections: 61)
# 2. hr senior specialist, san francisco bay area (connections: 500+ )
# 3. aspiring human resources management student seeking an internship, houston, texas area (connections: 500+ )
# 4. seeking human resources opportunities, chicago, illinois (connections: 390)
# 5. aspiring human resources management student seeking an internship, houston, texas area (connections: 500+ )
# 6. seeking human resources opportunities, chicago, illinois (connections: 390)
# 7. 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# 8. native english teacher at epik (english program in korea), kanada (connections: 500+ )
#
#
# --- Chunk 5 Instruction ---
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# 2. people development coordinator at ryan, denton, texas (connections: 500+ )
# 3. advisory board member at celal bayar university, i̇zmir, türkiye (connections: 500+ )
# 4. aspiring human resources specialist, greater new york city area (connections: 1)
# 5. student at humber college and aspiring human resources generalist, kanada (connections: 61)
# 6. hr senior specialist, san francisco bay area (connections: 500+ )
# 7. student at humber college and aspiring human resources generalist, kanada (connections: 61)
# 8. seeking human resources hris and generalist positions, greater philadelphia area (connections: 500+ )
#
#
# --- Chunk 6 Instruction ---
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. student at chapman university, lake forest, california (connections: 2)
# 2. svp, chro, marketing & communications, csr officer | engie | houston | the woodlands | energy | gphr | sphr, houston, texas area (connections: 500+ )
# 3. human resources coordinator at intercontinental buckhead atlanta, atlanta, georgia (connections: 500+ )
# 4. 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# 5. native english teacher at epik (english program in korea), kanada (connections: 500+ )
# 6. aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# 7. people development coordinator at ryan, denton, texas (connections: 500+ )
# 8. advisory board member at celal bayar university, i̇zmir, türkiye (connections: 500+ )
#
#
# --- Chunk 7 Instruction ---
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. aspiring human resources specialist, greater new york city area (connections: 1)
# 2. student at humber college and aspiring human resources generalist, kanada (connections: 61)
# 3. hr senior specialist, san francisco bay area (connections: 500+ )
# 4. student at humber college and aspiring human resources generalist, kanada (connections: 61)
# 5. seeking human resources hris and generalist positions, greater philadelphia area (connections: 500+ )
# 6. student at chapman university, lake forest, california (connections: 2)
# 7. svp, chro, marketing & communications, csr officer | engie | houston | the woodlands | energy | gphr | sphr, houston, texas area (connections: 500+ )
# 8. human resources coordinator at intercontinental buckhead atlanta, atlanta, georgia (connections: 500+ )
#
#
# --- Chunk 8 Instruction ---
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# 2. aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# 3. people development coordinator at ryan, denton, texas (connections: 500+ )
# 4. aspiring human resources specialist, greater new york city area (connections: 1)
# 5. hr senior specialist, san francisco bay area (connections: 500+ )
# 6. seeking human resources hris and generalist positions, greater philadelphia area (connections: 500+ )
# 7. student at chapman university, lake forest, california (connections: 2)
# 8. svp, chro, marketing & communications, csr officer | engie | houston | the woodlands | energy | gphr | sphr, houston, texas area (connections: 500+ )
#
#
# --- Chunk 9 Instruction ---
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. human resources coordinator at intercontinental buckhead atlanta, atlanta, georgia (connections: 500+ )
# 2. experienced retail manager and aspiring human resources professional, austin, texas area (connections: 57)
# 3. human resources, staffing and recruiting professional, jackson, mississippi area (connections: 500+ )
# 4. human resources specialist at luxottica, greater new york city area (connections: 500+ )
# 5. director of human resources north america, groupe beneteau, greater grand rapids, michigan area (connections: 500+ )
# 6. retired army national guard recruiter, office manager,  seeking a position in human resources., virginia beach, virginia (connections: 82)
# 7. human resources generalist at scottmadden, inc., raleigh-durham, north carolina area (connections: 500+ )
# 8. business management major and aspiring human resources manager, monroe, louisiana area (connections: 5)
#
#
# --- Chunk 10 Instruction ---
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. aspiring human resources manager, seeking internship in human resources., houston, texas area (connections: 7)
# 2. human resources professional, greater boston area (connections: 16)
# 3. nortia staffing is seeking human resources, payroll & administrative professionals!!  (408) 709-2621, san jose, california (connections: 500+ )
# 4. aspiring human resources professional | passionate about helping to create an inclusive and engaging work environment, new york, new york (connections: 212)
# 5. human resources|
# conflict management|
# policies & procedures|talent management|benefits & compensation, dallas/fort worth area (connections: 409)
# 6. human resources generalist at schwan's, amerika birleşik devletleri (connections: 500+ )
# 7. liberal arts major. aspiring human resources analyst., baton rouge, louisiana area (connections: 7)
# 8. junior mes engineer| information systems, myrtle beach, south carolina area (connections: 52)
#
#
# --- Chunk 11 Instruction ---
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. senior human resources business partner at heil environmental, chattanooga, tennessee area (connections: 455)
# 2. aspiring human resources professional | an energetic and team-focused leader, austin, texas area (connections: 174)
# 3. hr manager at endemol shine north america, los angeles, california (connections: 268)
# 4. human resources professional for the world leader in gis software, highland, california (connections: 50)
# 5. rrp brand portfolio executive at jti (japan tobacco international), greater philadelphia area (connections: 500+ )
# 6. information systems specialist and programmer with a love for data and organization., gaithersburg, maryland (connections: 4)
# 7. bachelor of science in biology from victoria university of wellington, baltimore, maryland (connections: 40)
# 8. human resources management major, milpitas, california (connections: 18)
#
#
# --- Chunk 12 Instruction ---
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. director human resources  at ey, greater atlanta area (connections: 349)
# 2. undergraduate research assistant at styczynski lab, greater atlanta area (connections: 155)
# 3. lead official at western illinois university, greater chicago area (connections: 39)
# 4. seeking employment opportunities within customer service or patient care, torrance, california (connections: 64)
# 5. admissions representative at community medical center long beach, long beach, california (connections: 9)
# 6. seeking human  resources opportunities. open to travel and relocation., amerika birleşik devletleri (connections: 415)
# 7. student at westfield state university, bridgewater, massachusetts (connections: 57)
# 8. student at indiana university kokomo - business management -
# retail manager at delphi hardware and paint, lafayette, indiana (connections: 19)
#
#
# --- Chunk 13 Instruction ---
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. aspiring human resources professional, kokomo, indiana area (connections: 71)
# 2. student, houston, texas area (connections: 4)
# 3. seeking human resources position, las vegas, nevada area (connections: 48)
# 4. aspiring human resources manager | graduating may 2020 | seeking an entry-level human resources position in st. louis, cape girardeau, missouri (connections: 103)
# 5. human resources generalist at loparex, raleigh-durham, north carolina area (connections: 500+ )
# 6. business intelligence and analytics at travelers, greater new york city area (connections: 49)
# 7. always set them up for success, greater los angeles area (connections: 500+ )
# 8. director of administration at excellence logging, katy, texas (connections: 500+ )

# %% [markdown]
# #### Apply the model and tokenizer to the chunks

# %%
# List to store decoded outputs for each chunk
chunk_outputs = []

# Loop over stored instructions
for chunk_idx, instruction in enumerate(chunk_instructions, start=1):
    # Build messages for the LLM
    messages = [
        {"role": "system", "content": "You are an expert HR ranking system. Output ONLY valid JSON."},
        {"role": "user", "content": instruction}
    ]

    # Apply chat template and tokenize
    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )
    inputs = tokenizer(prompt, return_tensors="pt").to("cpu")

    # Generate output
    outputs = model.generate(
        **inputs,
        max_new_tokens=1500,
        temperature=0.0,
        do_sample=False,
        pad_token_id=tokenizer.eos_token_id
    )

    # Decode output
    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
    chunk_outputs.append(decoded)

    # Preview output
    print(f"\n--- RAW OUTPUT for Chunk {chunk_idx} ---")
    print(decoded[:2000])  # show first 2000 chars
# Out:
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# --- RAW OUTPUT for Chunk 1 ---
# system
# You are an expert HR ranking system. Output ONLY valid JSON.
# user
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# 2. native english teacher at epik (english program in korea), kanada (connections: 500+ )
# 3. aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# 4. people development coordinator at ryan, denton, texas (connections: 500+ )
# 5. advisory board member at celal bayar university, i̇zmir, türkiye (connections: 500+ )
# 6. aspiring human resources specialist, greater new york city area (connections: 1)
# 7. student at humber college and aspiring human resources generalist, kanada (connections: 61)
# 8. hr senior specialist, san francisco bay area (connections: 500+ )
#
# assistant
# [
#   {"index": 1, "score": 0.95},
#   {"index": 2, "score": 0.90},
#   {"index": 3, "score": 0.85},
#   {"index": 4, "score": 0.80},
#   {"index": 5, "score": 0.75},
#   {"index": 6, "score": 0.70},
#   {"index": 7, "score": 0.65},
#   {"index": 8, "score": 0.60}
# ]
#
# --- RAW OUTPUT for Chunk 2 ---
# system
# You are an expert HR ranking system. Output ONLY valid JSON.
# user
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. student at humber college and aspiring human resources generalist, kanada (connections: 61)
# 2. seeking human resources hris and generalist positions, greater philadelphia area (connections: 500+ )
# 3. student at chapman university, lake forest, california (connections: 2)
# 4. svp, chro, marketing & communications, csr officer | engie | houston | the woodlands | energy | gphr | sphr, houston, texas area (connections: 500+ )
# 5. human resources coordinator at intercontinental buckhead atlanta, atlanta, georgia (connections: 500+ )
# 6. 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# 7. 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# 8. native english teacher at epik (english program in korea), kanada (connections: 500+ )
#
# assistant
# [
#   {"index": 1, "score": 0.00},
#   {"index": 2, "score": 0.00},
#   {"index": 3, "score": 0.00},
#   {"index": 4, "score": 0.00},
#   {"index": 5, "score": 0.00},
#   {"index": 6, "score": 0.00},
#   {"index": 7, "score": 0.00},
#   {"index": 8, "score": 0.00}
# ]
#
# --- RAW OUTPUT for Chunk 3 ---
# system
# You are an expert HR ranking system. Output ONLY valid JSON.
# user
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# 2. people development coordinator at ryan, denton, texas (connections: 500+ )
# 3. 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# 4. native english teacher at epik (english program in korea), kanada (connections: 500+ )
# 5. aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# 6. people development coordinator at ryan, denton, texas (connections: 500+ )
# 7. advisory board member at celal bayar university, i̇zmir, türkiye (connections: 500+ )
# 8. aspiring human resources specialist, greater new york city area (connections: 1)
#
# assistant
# [
#   {"index": 1, "score": 0.95},
#   {"index": 2, "score": 0.95},
#   {"index": 3, "score": 0.95},
#   {"index": 4, "score": 0.95},
#   {"index": 5, "score": 0.95},
#   {"index": 6, "score": 0.95},
#   {"index": 7, "score": 0.95},
#   {"index": 8, "score": 0.95}
# ]
#
# --- RAW OUTPUT for Chunk 4 ---
# system
# You are an expert HR ranking system. Output ONLY valid JSON.
# user
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. student at humber college and aspiring human resources generalist, kanada (connections: 61)
# 2. hr senior specialist, san francisco bay area (connections: 500+ )
# 3. aspiring human resources management student seeking an internship, houston, texas area (connections: 500+ )
# 4. seeking human resources opportunities, chicago, illinois (connections: 390)
# 5. aspiring human resources management student seeking an internship, houston, texas area (connections: 500+ )
# 6. seeking human resources opportunities, chicago, illinois (connections: 390)
# 7. 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# 8. native english teacher at epik (english program in korea), kanada (connections: 500+ )
#
# assistant
# [
#   {"index": 1, "score": 0.00},
#   {"index": 2, "score": 0.00},
#   {"index": 3, "score": 0.00},
#   {"index": 4, "score": 0.00},
#   {"index": 5, "score": 0.00},
#   {"index": 6, "score": 0.00},
#   {"index": 7, "score": 0.00},
#   {"index": 8, "score": 0.00}
# ]
#
# --- RAW OUTPUT for Chunk 5 ---
# system
# You are an expert HR ranking system. Output ONLY valid JSON.
# user
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# 2. people development coordinator at ryan, denton, texas (connections: 500+ )
# 3. advisory board member at celal bayar university, i̇zmir, türkiye (connections: 500+ )
# 4. aspiring human resources specialist, greater new york city area (connections: 1)
# 5. student at humber college and aspiring human resources generalist, kanada (connections: 61)
# 6. hr senior specialist, san francisco bay area (connections: 500+ )
# 7. student at humber college and aspiring human resources generalist, kanada (connections: 61)
# 8. seeking human resources hris and generalist positions, greater philadelphia area (connections: 500+ )
#
# assistant
# [
#   {"index": 1, "score": 0.95},
#   {"index": 2, "score": 0.95},
#   {"index": 3, "score": 0.95},
#   {"index": 4, "score": 0.95},
#   {"index": 5, "score": 0.95},
#   {"index": 6, "score": 0.95},
#   {"index": 7, "score": 0.95},
#   {"index": 8, "score": 0.95}
# ]
#
# --- RAW OUTPUT for Chunk 6 ---
# system
# You are an expert HR ranking system. Output ONLY valid JSON.
# user
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. student at chapman university, lake forest, california (connections: 2)
# 2. svp, chro, marketing & communications, csr officer | engie | houston | the woodlands | energy | gphr | sphr, houston, texas area (connections: 500+ )
# 3. human resources coordinator at intercontinental buckhead atlanta, atlanta, georgia (connections: 500+ )
# 4. 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# 5. native english teacher at epik (english program in korea), kanada (connections: 500+ )
# 6. aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# 7. people development coordinator at ryan, denton, texas (connections: 500+ )
# 8. advisory board member at celal bayar university, i̇zmir, türkiye (connections: 500+ )
#
# assistant
# [
#   {"index": 1, "score": 0.00},
#   {"index": 2, "score": 0.00},
#   {"index": 3, "score": 0.00},
#   {"index": 4, "score": 0.00},
#   {"index": 5, "score": 0.00},
#   {"index": 6, "score": 0.00},
#   {"index": 7, "score": 0.00},
#   {"index": 8, "score": 0.00}
# ]
#
# --- RAW OUTPUT for Chunk 7 ---
# system
# You are an expert HR ranking system. Output ONLY valid JSON.
# user
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. aspiring human resources specialist, greater new york city area (connections: 1)
# 2. student at humber college and aspiring human resources generalist, kanada (connections: 61)
# 3. hr senior specialist, san francisco bay area (connections: 500+ )
# 4. student at humber college and aspiring human resources generalist, kanada (connections: 61)
# 5. seeking human resources hris and generalist positions, greater philadelphia area (connections: 500+ )
# 6. student at chapman university, lake forest, california (connections: 2)
# 7. svp, chro, marketing & communications, csr officer | engie | houston | the woodlands | energy | gphr | sphr, houston, texas area (connections: 500+ )
# 8. human resources coordinator at intercontinental buckhead atlanta, atlanta, georgia (connections: 500+ )
#
# assistant
# [
#   {"index": 1, "score": 0.00},
#   {"index": 2, "score": 0.00},
#   {"index": 3, "score": 0.00},
#   {"index": 4, "score": 0.00},
#   {"index": 5, "score": 0.00},
#   {"index": 6, "score": 0.00},
#   {"index": 7, "score": 0.00},
#   {"index": 8, "score": 0.00}
# ]
#
# --- RAW OUTPUT for Chunk 8 ---
# system
# You are an expert HR ranking system. Output ONLY valid JSON.
# user
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# 2. aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# 3. people development coordinator at ryan, denton, texas (connections: 500+ )
# 4. aspiring human resources specialist, greater new york city area (connections: 1)
# 5. hr senior specialist, san francisco bay area (connections: 500+ )
# 6. seeking human resources hris and generalist positions, greater philadelphia area (connections: 500+ )
# 7. student at chapman university, lake forest, california (connections: 2)
# 8. svp, chro, marketing & communications, csr officer | engie | houston | the woodlands | energy | gphr | sphr, houston, texas area (connections: 500+ )
#
# assistant
# [
#   {"index": 1, "score": 0.95},
#   {"index": 2, "score": 0.90},
#   {"index": 3, "score": 0.85},
#   {"index": 4, "score": 0.80},
#   {"index": 5, "score": 0.75},
#   {"index": 6, "score": 0.70},
#   {"index": 7, "score": 0.65},
#   {"index": 8, "score": 0.60}
# ]
#
# --- RAW OUTPUT for Chunk 9 ---
# system
# You are an expert HR ranking system. Output ONLY valid JSON.
# user
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. human resources coordinator at intercontinental buckhead atlanta, atlanta, georgia (connections: 500+ )
# 2. experienced retail manager and aspiring human resources professional, austin, texas area (connections: 57)
# 3. human resources, staffing and recruiting professional, jackson, mississippi area (connections: 500+ )
# 4. human resources specialist at luxottica, greater new york city area (connections: 500+ )
# 5. director of human resources north america, groupe beneteau, greater grand rapids, michigan area (connections: 500+ )
# 6. retired army national guard recruiter, office manager,  seeking a position in human resources., virginia beach, virginia (connections: 82)
# 7. human resources generalist at scottmadden, inc., raleigh-durham, north carolina area (connections: 500+ )
# 8. business management major and aspiring human resources manager, monroe, louisiana area (connections: 5)
#
# assistant
# [
#   {"index": 1, "score": 0.95},
#   {"index": 2, "score": 0.85},
#   {"index": 3, "score": 0.85},
#   {"index": 4, "score": 0.85},
#   {"index": 5, "score": 0.85},
#   {"index": 6, "score": 0.85},
#   {"index": 7, "score": 0.85},
#   {"index": 8, "score": 0.85}
# ]
#
# --- RAW OUTPUT for Chunk 10 ---
# system
# You are an expert HR ranking system. Output ONLY valid JSON.
# user
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. aspiring human resources manager, seeking internship in human resources., houston, texas area (connections: 7)
# 2. human resources professional, greater boston area (connections: 16)
# 3. nortia staffing is seeking human resources, payroll & administrative professionals!!  (408) 709-2621, san jose, california (connections: 500+ )
# 4. aspiring human resources professional | passionate about helping to create an inclusive and engaging work environment, new york, new york (connections: 212)
# 5. human resources|
# conflict management|
# policies & procedures|talent management|benefits & compensation, dallas/fort worth area (connections: 409)
# 6. human resources generalist at schwan's, amerika birleşik devletleri (connections: 500+ )
# 7. liberal arts major. aspiring human resources analyst., baton rouge, louisiana area (connections: 7)
# 8. junior mes engineer| information systems, myrtle beach, south carolina area (connections: 52)
#
# assistant
# [
#   {"index": 1, "score": 0.85},
#   {"index": 2, "score": 0.75},
#   {"index": 3, "score": 0.65},
#   {"index": 4, "score": 0.55},
#   {"index": 5, "score": 0.45},
#   {"index": 6, "score": 0.35},
#   {"index": 7, "score": 0.25},
#   {"index": 8, "score": 0.15}
# ]
#
# --- RAW OUTPUT for Chunk 11 ---
# system
# You are an expert HR ranking system. Output ONLY valid JSON.
# user
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. senior human resources business partner at heil environmental, chattanooga, tennessee area (connections: 455)
# 2. aspiring human resources professional | an energetic and team-focused leader, austin, texas area (connections: 174)
# 3. hr manager at endemol shine north america, los angeles, california (connections: 268)
# 4. human resources professional for the world leader in gis software, highland, california (connections: 50)
# 5. rrp brand portfolio executive at jti (japan tobacco international), greater philadelphia area (connections: 500+ )
# 6. information systems specialist and programmer with a love for data and organization., gaithersburg, maryland (connections: 4)
# 7. bachelor of science in biology from victoria university of wellington, baltimore, maryland (connections: 40)
# 8. human resources management major, milpitas, california (connections: 18)
#
# assistant
# [
#   {"index": 1, "score": 0.95},
#   {"index": 2, "score": 0.85},
#   {"index": 3, "score": 0.75},
#   {"index": 4, "score": 0.65},
#   {"index": 5, "score": 0.55},
#   {"index": 6, "score": 0.45},
#   {"index": 7, "score": 0.35},
#   {"index": 8, "score": 0.25}
# ]
#
# --- RAW OUTPUT for Chunk 12 ---
# system
# You are an expert HR ranking system. Output ONLY valid JSON.
# user
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. director human resources  at ey, greater atlanta area (connections: 349)
# 2. undergraduate research assistant at styczynski lab, greater atlanta area (connections: 155)
# 3. lead official at western illinois university, greater chicago area (connections: 39)
# 4. seeking employment opportunities within customer service or patient care, torrance, california (connections: 64)
# 5. admissions representative at community medical center long beach, long beach, california (connections: 9)
# 6. seeking human  resources opportunities. open to travel and relocation., amerika birleşik devletleri (connections: 415)
# 7. student at westfield state university, bridgewater, massachusetts (connections: 57)
# 8. student at indiana university kokomo - business management -
# retail manager at delphi hardware and paint, lafayette, indiana (connections: 19)
#
# assistant
# [
#   {"index": 1, "score": 0.95},
#   {"index": 2, "score": 0.90},
#   {"index": 3, "score": 0.85},
#   {"index": 4, "score": 0.80},
#   {"index": 5, "score": 0.75},
#   {"index": 6, "score": 0.70},
#   {"index": 7, "score": 0.65},
#   {"index": 8, "score": 0.60}
# ]
#
# --- RAW OUTPUT for Chunk 13 ---
# system
# You are an expert HR ranking system. Output ONLY valid JSON.
# user
#
# Rank each candidate for relevance to: "aspiring human resources OR seeking human resources"
#
# IMPORTANT:
# - Output ONLY a JSON array.
# - Each item must have "index" and "score".
# - Score must be between 0 and 1.
# - Include ALL candidates.
# - Round scores to EXACTLY 2 decimals.
# - Do NOT truncate output.
# - Do NOT duplicate candidate
#
# Example (do NOT copy scores):
# [
#   {"index": 1, "score": <score>},
#   {"index": 2, "score": <score>}
# ]
#
# Candidates:
# 1. aspiring human resources professional, kokomo, indiana area (connections: 71)
# 2. student, houston, texas area (connections: 4)
# 3. seeking human resources position, las vegas, nevada area (connections: 48)
# 4. aspiring human resources manager | graduating may 2020 | seeking an entry-level human resources position in st. louis, cape girardeau, missouri (connections: 103)
# 5. human resources generalist at loparex, raleigh-durham, north carolina area (connections: 500+ )
# 6. business intelligence and analytics at travelers, greater new york city area (connections: 49)
# 7. always set them up for success, greater los angeles area (connections: 500+ )
# 8. director of administration at excellence logging, katy, texas (connections: 500+ )
#
# assistant
# [
#   {"index": 1, "score": 0.95},
#   {"index": 2, "score": 0.00},
#   {"index": 3, "score": 0.00},
#   {"index": 4, "score": 0.00},
#   {"index": 5, "score": 0.00},
#   {"index": 6, "score": 0.00},
#   {"index": 7, "score": 0.00},
#   {"index": 8, "score": 0.00}
# ]

# %% [markdown]
# #### Extract jsons fron the model's response

# %%
parsed_chunks = []

for idx, decoded in enumerate(chunk_outputs, start=1):

    print("\n========================")
    print(f"DEBUG for Chunk {idx}")
    print("========================")

    # 1. Find where the assistant's answer begins
    assistant_split = decoded.split("assistant", 1)
    if len(assistant_split) < 2:
        print("ERROR: Could not find assistant response.")
        continue

    assistant_text = assistant_split[1]  # keep only assistant reply

    # 2. Search for JSON *only* inside the assistant section
    match = re.search(r"\[\s*\{.*?\}\s*\]", assistant_text, re.DOTALL)

    if match:
        json_str = match.group(0)
        print("Extracted JSON string:")
        print(json_str)

        try:
            parsed = json.loads(json_str)
            parsed_chunks.append(parsed)
            print("\nParsed JSON OK!")
        except json.JSONDecodeError as e:
            print("JSONDecodeError:", e)
    else:
        print("No JSON found inside assistant reply.")
# Out:
# ========================
# DEBUG for Chunk 1
# ========================
# Extracted JSON string:
# [
#   {"index": 1, "score": 0.95},
#   {"index": 2, "score": 0.90},
#   {"index": 3, "score": 0.85},
#   {"index": 4, "score": 0.80},
#   {"index": 5, "score": 0.75},
#   {"index": 6, "score": 0.70},
#   {"index": 7, "score": 0.65},
#   {"index": 8, "score": 0.60}
# ]
#
# Parsed JSON OK!
#
# ========================
# DEBUG for Chunk 2
# ========================
# Extracted JSON string:
# [
#   {"index": 1, "score": 0.00},
#   {"index": 2, "score": 0.00},
#   {"index": 3, "score": 0.00},
#   {"index": 4, "score": 0.00},
#   {"index": 5, "score": 0.00},
#   {"index": 6, "score": 0.00},
#   {"index": 7, "score": 0.00},
#   {"index": 8, "score": 0.00}
# ]
#
# Parsed JSON OK!
#
# ========================
# DEBUG for Chunk 3
# ========================
# Extracted JSON string:
# [
#   {"index": 1, "score": 0.95},
#   {"index": 2, "score": 0.95},
#   {"index": 3, "score": 0.95},
#   {"index": 4, "score": 0.95},
#   {"index": 5, "score": 0.95},
#   {"index": 6, "score": 0.95},
#   {"index": 7, "score": 0.95},
#   {"index": 8, "score": 0.95}
# ]
#
# Parsed JSON OK!
#
# ========================
# DEBUG for Chunk 4
# ========================
# Extracted JSON string:
# [
#   {"index": 1, "score": 0.00},
#   {"index": 2, "score": 0.00},
#   {"index": 3, "score": 0.00},
#   {"index": 4, "score": 0.00},
#   {"index": 5, "score": 0.00},
#   {"index": 6, "score": 0.00},
#   {"index": 7, "score": 0.00},
#   {"index": 8, "score": 0.00}
# ]
#
# Parsed JSON OK!
#
# ========================
# DEBUG for Chunk 5
# ========================
# Extracted JSON string:
# [
#   {"index": 1, "score": 0.95},
#   {"index": 2, "score": 0.95},
#   {"index": 3, "score": 0.95},
#   {"index": 4, "score": 0.95},
#   {"index": 5, "score": 0.95},
#   {"index": 6, "score": 0.95},
#   {"index": 7, "score": 0.95},
#   {"index": 8, "score": 0.95}
# ]
#
# Parsed JSON OK!
#
# ========================
# DEBUG for Chunk 6
# ========================
# Extracted JSON string:
# [
#   {"index": 1, "score": 0.00},
#   {"index": 2, "score": 0.00},
#   {"index": 3, "score": 0.00},
#   {"index": 4, "score": 0.00},
#   {"index": 5, "score": 0.00},
#   {"index": 6, "score": 0.00},
#   {"index": 7, "score": 0.00},
#   {"index": 8, "score": 0.00}
# ]
#
# Parsed JSON OK!
#
# ========================
# DEBUG for Chunk 7
# ========================
# Extracted JSON string:
# [
#   {"index": 1, "score": 0.00},
#   {"index": 2, "score": 0.00},
#   {"index": 3, "score": 0.00},
#   {"index": 4, "score": 0.00},
#   {"index": 5, "score": 0.00},
#   {"index": 6, "score": 0.00},
#   {"index": 7, "score": 0.00},
#   {"index": 8, "score": 0.00}
# ]
#
# Parsed JSON OK!
#
# ========================
# DEBUG for Chunk 8
# ========================
# Extracted JSON string:
# [
#   {"index": 1, "score": 0.95},
#   {"index": 2, "score": 0.90},
#   {"index": 3, "score": 0.85},
#   {"index": 4, "score": 0.80},
#   {"index": 5, "score": 0.75},
#   {"index": 6, "score": 0.70},
#   {"index": 7, "score": 0.65},
#   {"index": 8, "score": 0.60}
# ]
#
# Parsed JSON OK!
#
# ========================
# DEBUG for Chunk 9
# ========================
# Extracted JSON string:
# [
#   {"index": 1, "score": 0.95},
#   {"index": 2, "score": 0.85},
#   {"index": 3, "score": 0.85},
#   {"index": 4, "score": 0.85},
#   {"index": 5, "score": 0.85},
#   {"index": 6, "score": 0.85},
#   {"index": 7, "score": 0.85},
#   {"index": 8, "score": 0.85}
# ]
#
# Parsed JSON OK!
#
# ========================
# DEBUG for Chunk 10
# ========================
# Extracted JSON string:
# [
#   {"index": 1, "score": 0.85},
#   {"index": 2, "score": 0.75},
#   {"index": 3, "score": 0.65},
#   {"index": 4, "score": 0.55},
#   {"index": 5, "score": 0.45},
#   {"index": 6, "score": 0.35},
#   {"index": 7, "score": 0.25},
#   {"index": 8, "score": 0.15}
# ]
#
# Parsed JSON OK!
#
# ========================
# DEBUG for Chunk 11
# ========================
# Extracted JSON string:
# [
#   {"index": 1, "score": 0.95},
#   {"index": 2, "score": 0.85},
#   {"index": 3, "score": 0.75},
#   {"index": 4, "score": 0.65},
#   {"index": 5, "score": 0.55},
#   {"index": 6, "score": 0.45},
#   {"index": 7, "score": 0.35},
#   {"index": 8, "score": 0.25}
# ]
#
# Parsed JSON OK!
#
# ========================
# DEBUG for Chunk 12
# ========================
# Extracted JSON string:
# [
#   {"index": 1, "score": 0.95},
#   {"index": 2, "score": 0.90},
#   {"index": 3, "score": 0.85},
#   {"index": 4, "score": 0.80},
#   {"index": 5, "score": 0.75},
#   {"index": 6, "score": 0.70},
#   {"index": 7, "score": 0.65},
#   {"index": 8, "score": 0.60}
# ]
#
# Parsed JSON OK!
#
# ========================
# DEBUG for Chunk 13
# ========================
# Extracted JSON string:
# [
#   {"index": 1, "score": 0.95},
#   {"index": 2, "score": 0.00},
#   {"index": 3, "score": 0.00},
#   {"index": 4, "score": 0.00},
#   {"index": 5, "score": 0.00},
#   {"index": 6, "score": 0.00},
#   {"index": 7, "score": 0.00},
#   {"index": 8, "score": 0.00}
# ]
#
# Parsed JSON OK!

# %% [markdown]
# ##### Merge the extracted jsons back the original dataframe(df)

# %%
# Final list 
merged_results = []

# Flatten parsed chunks and attach to original df
global_index = 0

for chunk_idx, chunk_scores in enumerate(parsed_chunks, start=1):

    for item in chunk_scores:
        score = float(item["score"])         # ensure score is float
        df.loc[global_index, "qwen_score"] = score   # correct Pandas assignment
        merged_results.append({
            "id": df.loc[global_index, "id"],
            "text": df.loc[global_index, "text"],
            "qwen_score": score
        })
        global_index += 1

# Preview
#print("\n=== MERGED RESULTS (items) ===")
for r in merged_results[:104]:
    print(r["id"], r["text"], "→", r["qwen_score"])
# Out:
# 1 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85) → 0.95
# 2 native english teacher at epik (english program in korea), kanada (connections: 500+ ) → 0.9
# 3 aspiring human resources professional, raleigh-durham, north carolina area (connections: 44) → 0.85
# 4 people development coordinator at ryan, denton, texas (connections: 500+ ) → 0.8
# 5 advisory board member at celal bayar university, i̇zmir, türkiye (connections: 500+ ) → 0.75
# 6 aspiring human resources specialist, greater new york city area (connections: 1) → 0.7
# 7 student at humber college and aspiring human resources generalist, kanada (connections: 61) → 0.65
# 8 hr senior specialist, san francisco bay area (connections: 500+ ) → 0.6
# 9 student at humber college and aspiring human resources generalist, kanada (connections: 61) → 0.0
# 10 seeking human resources hris and generalist positions, greater philadelphia area (connections: 500+ ) → 0.0
# 11 student at chapman university, lake forest, california (connections: 2) → 0.0
# 12 svp, chro, marketing & communications, csr officer | engie | houston | the woodlands | energy | gphr | sphr, houston, texas area (connections: 500+ ) → 0.0
# 13 human resources coordinator at intercontinental buckhead atlanta, atlanta, georgia (connections: 500+ ) → 0.0
# 14 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85) → 0.0
# 15 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85) → 0.0
# 16 native english teacher at epik (english program in korea), kanada (connections: 500+ ) → 0.0
# 17 aspiring human resources professional, raleigh-durham, north carolina area (connections: 44) → 0.95
# 18 people development coordinator at ryan, denton, texas (connections: 500+ ) → 0.95
# 19 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85) → 0.95
# 20 native english teacher at epik (english program in korea), kanada (connections: 500+ ) → 0.95
# 21 aspiring human resources professional, raleigh-durham, north carolina area (connections: 44) → 0.95
# 22 people development coordinator at ryan, denton, texas (connections: 500+ ) → 0.95
# 23 advisory board member at celal bayar university, i̇zmir, türkiye (connections: 500+ ) → 0.95
# 24 aspiring human resources specialist, greater new york city area (connections: 1) → 0.95
# 25 student at humber college and aspiring human resources generalist, kanada (connections: 61) → 0.0
# 26 hr senior specialist, san francisco bay area (connections: 500+ ) → 0.0
# 27 aspiring human resources management student seeking an internship, houston, texas area (connections: 500+ ) → 0.0
# 28 seeking human resources opportunities, chicago, illinois (connections: 390) → 0.0
# 29 aspiring human resources management student seeking an internship, houston, texas area (connections: 500+ ) → 0.0
# 30 seeking human resources opportunities, chicago, illinois (connections: 390) → 0.0
# 31 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85) → 0.0
# 32 native english teacher at epik (english program in korea), kanada (connections: 500+ ) → 0.0
# 33 aspiring human resources professional, raleigh-durham, north carolina area (connections: 44) → 0.95
# 34 people development coordinator at ryan, denton, texas (connections: 500+ ) → 0.95
# 35 advisory board member at celal bayar university, i̇zmir, türkiye (connections: 500+ ) → 0.95
# 36 aspiring human resources specialist, greater new york city area (connections: 1) → 0.95
# 37 student at humber college and aspiring human resources generalist, kanada (connections: 61) → 0.95
# 38 hr senior specialist, san francisco bay area (connections: 500+ ) → 0.95
# 39 student at humber college and aspiring human resources generalist, kanada (connections: 61) → 0.95
# 40 seeking human resources hris and generalist positions, greater philadelphia area (connections: 500+ ) → 0.95
# 41 student at chapman university, lake forest, california (connections: 2) → 0.0
# 42 svp, chro, marketing & communications, csr officer | engie | houston | the woodlands | energy | gphr | sphr, houston, texas area (connections: 500+ ) → 0.0
# 43 human resources coordinator at intercontinental buckhead atlanta, atlanta, georgia (connections: 500+ ) → 0.0
# 44 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85) → 0.0
# 45 native english teacher at epik (english program in korea), kanada (connections: 500+ ) → 0.0
# 46 aspiring human resources professional, raleigh-durham, north carolina area (connections: 44) → 0.0
# 47 people development coordinator at ryan, denton, texas (connections: 500+ ) → 0.0
# 48 advisory board member at celal bayar university, i̇zmir, türkiye (connections: 500+ ) → 0.0
# 49 aspiring human resources specialist, greater new york city area (connections: 1) → 0.0
# 50 student at humber college and aspiring human resources generalist, kanada (connections: 61) → 0.0
# 51 hr senior specialist, san francisco bay area (connections: 500+ ) → 0.0
# 52 student at humber college and aspiring human resources generalist, kanada (connections: 61) → 0.0
# 53 seeking human resources hris and generalist positions, greater philadelphia area (connections: 500+ ) → 0.0
# 54 student at chapman university, lake forest, california (connections: 2) → 0.0
# 55 svp, chro, marketing & communications, csr officer | engie | houston | the woodlands | energy | gphr | sphr, houston, texas area (connections: 500+ ) → 0.0
# 56 human resources coordinator at intercontinental buckhead atlanta, atlanta, georgia (connections: 500+ ) → 0.0
# 57 2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85) → 0.95
# 58 aspiring human resources professional, raleigh-durham, north carolina area (connections: 44) → 0.9
# 59 people development coordinator at ryan, denton, texas (connections: 500+ ) → 0.85
# 60 aspiring human resources specialist, greater new york city area (connections: 1) → 0.8
# 61 hr senior specialist, san francisco bay area (connections: 500+ ) → 0.75
# 62 seeking human resources hris and generalist positions, greater philadelphia area (connections: 500+ ) → 0.7
# 63 student at chapman university, lake forest, california (connections: 2) → 0.65
# 64 svp, chro, marketing & communications, csr officer | engie | houston | the woodlands | energy | gphr | sphr, houston, texas area (connections: 500+ ) → 0.6
# 65 human resources coordinator at intercontinental buckhead atlanta, atlanta, georgia (connections: 500+ ) → 0.95
# 66 experienced retail manager and aspiring human resources professional, austin, texas area (connections: 57) → 0.85
# 67 human resources, staffing and recruiting professional, jackson, mississippi area (connections: 500+ ) → 0.85
# 68 human resources specialist at luxottica, greater new york city area (connections: 500+ ) → 0.85
# 69 director of human resources north america, groupe beneteau, greater grand rapids, michigan area (connections: 500+ ) → 0.85
# 70 retired army national guard recruiter, office manager,  seeking a position in human resources., virginia beach, virginia (connections: 82) → 0.85
# 71 human resources generalist at scottmadden, inc., raleigh-durham, north carolina area (connections: 500+ ) → 0.85
# 72 business management major and aspiring human resources manager, monroe, louisiana area (connections: 5) → 0.85
# 73 aspiring human resources manager, seeking internship in human resources., houston, texas area (connections: 7) → 0.85
# 74 human resources professional, greater boston area (connections: 16) → 0.75
# 75 nortia staffing is seeking human resources, payroll & administrative professionals!!  (408) 709-2621, san jose, california (connections: 500+ ) → 0.65
# 76 aspiring human resources professional | passionate about helping to create an inclusive and engaging work environment, new york, new york (connections: 212) → 0.55
# 77 human resources|
# conflict management|
# policies & procedures|talent management|benefits & compensation, dallas/fort worth area (connections: 409) → 0.45
# 78 human resources generalist at schwan's, amerika birleşik devletleri (connections: 500+ ) → 0.35
# 79 liberal arts major. aspiring human resources analyst., baton rouge, louisiana area (connections: 7) → 0.25
# 80 junior mes engineer| information systems, myrtle beach, south carolina area (connections: 52) → 0.15
# 81 senior human resources business partner at heil environmental, chattanooga, tennessee area (connections: 455) → 0.95
# 82 aspiring human resources professional | an energetic and team-focused leader, austin, texas area (connections: 174) → 0.85
# 83 hr manager at endemol shine north america, los angeles, california (connections: 268) → 0.75
# 84 human resources professional for the world leader in gis software, highland, california (connections: 50) → 0.65
# 85 rrp brand portfolio executive at jti (japan tobacco international), greater philadelphia area (connections: 500+ ) → 0.55
# 86 information systems specialist and programmer with a love for data and organization., gaithersburg, maryland (connections: 4) → 0.45
# 87 bachelor of science in biology from victoria university of wellington, baltimore, maryland (connections: 40) → 0.35
# 88 human resources management major, milpitas, california (connections: 18) → 0.25
# 89 director human resources  at ey, greater atlanta area (connections: 349) → 0.95
# 90 undergraduate research assistant at styczynski lab, greater atlanta area (connections: 155) → 0.9
# 91 lead official at western illinois university, greater chicago area (connections: 39) → 0.85
# 92 seeking employment opportunities within customer service or patient care, torrance, california (connections: 64) → 0.8
# 93 admissions representative at community medical center long beach, long beach, california (connections: 9) → 0.75
# 94 seeking human  resources opportunities. open to travel and relocation., amerika birleşik devletleri (connections: 415) → 0.7
# 95 student at westfield state university, bridgewater, massachusetts (connections: 57) → 0.65
# 96 student at indiana university kokomo - business management -
# retail manager at delphi hardware and paint, lafayette, indiana (connections: 19) → 0.6
# 97 aspiring human resources professional, kokomo, indiana area (connections: 71) → 0.95
# 98 student, houston, texas area (connections: 4) → 0.0
# 99 seeking human resources position, las vegas, nevada area (connections: 48) → 0.0
# 100 aspiring human resources manager | graduating may 2020 | seeking an entry-level human resources position in st. louis, cape girardeau, missouri (connections: 103) → 0.0
# 101 human resources generalist at loparex, raleigh-durham, north carolina area (connections: 500+ ) → 0.0
# 102 business intelligence and analytics at travelers, greater new york city area (connections: 49) → 0.0
# 103 always set them up for success, greater los angeles area (connections: 500+ ) → 0.0
# 104 director of administration at excellence logging, katy, texas (connections: 500+ ) → 0.0

# %% [markdown]
# #### sort the candidates in ascending order using qwen_score

# %%
# Sort by qwen score, highest first
df_sorted = df.sort_values(by="qwen_score", ascending=False).reset_index(drop=True)

# Preview top 20 candidates
df_sorted[["id", "text", "qwen_score"]].head(20)
# Out:
#     id                                               text  qwen_score
# 0    1  2019 c.t. bauer college of business graduate (...        0.95
# 1   18  people development coordinator at ryan, denton...        0.95
# 2   19  2019 c.t. bauer college of business graduate (...        0.95
# 3   20  native english teacher at epik (english progra...        0.95
# 4   21  aspiring human resources professional, raleigh...        0.95
# 5   22  people development coordinator at ryan, denton...        0.95
# 6   23  advisory board member at celal bayar universit...        0.95
# 7   24  aspiring human resources specialist, greater n...        0.95
# 8   33  aspiring human resources professional, raleigh...        0.95
# 9   34  people development coordinator at ryan, denton...        0.95
# 10  35  advisory board member at celal bayar universit...        0.95
# 11  36  aspiring human resources specialist, greater n...        0.95
# 12  37  student at humber college and aspiring human r...        0.95
# 13  38  hr senior specialist, san francisco bay area (...        0.95
# 14  39  student at humber college and aspiring human r...        0.95
# 15  17  aspiring human resources professional, raleigh...        0.95
# 16  40  seeking human resources hris and generalist po...        0.95
# 17  89  director human resources  at ey, greater atlan...        0.95
# 18  57  2019 c.t. bauer college of business graduate (...        0.95
# 19  97  aspiring human resources professional, kokomo,...        0.95

# %% [markdown]
# #### print full lenght of the text column for starring.

# %%
pd.set_option('display.max_colwidth', None)

df_sorted[["id", "text", "qwen_score"]].head(20)
# Out:
#     id  \
# 0    1
# 1   18
# 2   19
# 3   20
# 4   21
# 5   22
# 6   23
# 7   24
# 8   33
# 9   34
# 10  35
# 11  36
# 12  37
# 13  38
# 14  39
# 15  17
# 16  40
# 17  89
# 18  57
# 19  97
#
#                                                                                                                                           text  \
# 0   2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# 1                                                                   people development coordinator at ryan, denton, texas (connections: 500+ )
# 2   2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# 3                                                       native english teacher at epik (english program in korea), kanada (connections: 500+ )
# 4                                                 aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# 5                                                                   people development coordinator at ryan, denton, texas (connections: 500+ )
# 6                                                        advisory board member at celal bayar university, i̇zmir, türkiye (connections: 500+ )
# 7                                                             aspiring human resources specialist, greater new york city area (connections: 1)
# 8                                                 aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# 9                                                                   people development coordinator at ryan, denton, texas (connections: 500+ )
# 10                                                       advisory board member at celal bayar university, i̇zmir, türkiye (connections: 500+ )
# 11                                                            aspiring human resources specialist, greater new york city area (connections: 1)
# 12                                                 student at humber college and aspiring human resources generalist, kanada (connections: 61)
# 13                                                                           hr senior specialist, san francisco bay area (connections: 500+ )
# 14                                                 student at humber college and aspiring human resources generalist, kanada (connections: 61)
# 15                                                aspiring human resources professional, raleigh-durham, north carolina area (connections: 44)
# 16                                       seeking human resources hris and generalist positions, greater philadelphia area (connections: 500+ )
# 17                                                                    director human resources  at ey, greater atlanta area (connections: 349)
# 18  2019 c.t. bauer college of business graduate (magna cum laude) and aspiring human resources professional, houston, texas (connections: 85)
# 19                                                               aspiring human resources professional, kokomo, indiana area (connections: 71)
#
#     qwen_score
# 0         0.95
# 1         0.95
# 2         0.95
# 3         0.95
# 4         0.95
# 5         0.95
# 6         0.95
# 7         0.95
# 8         0.95
# 9         0.95
# 10        0.95
# 11        0.95
# 12        0.95
# 13        0.95
# 14        0.95
# 15        0.95
# 16        0.95
# 17        0.95
# 18        0.95
# 19        0.95

# %% [markdown]
# #### save it as csv file for reuse

# %%
df_sorted[["id", "text", "llm_score"]].head(20).to_csv(r"C:\Users\USER\Documents\Potential Talent\Qwen_2.5-3b\Qwen_top20_candidate.csv", index=False)
print("df_sorted saved")
# Out:
# df_sorted saved
